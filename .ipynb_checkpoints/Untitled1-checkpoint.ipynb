# %%
import automutualinformation
import pickle

# Load The Sequences!
with open('symbolic_sequences_pup2mother_All.pkl','rb') as f:
    symbolic_sequences = pickle.load(f)

# %%
symbolic_sequences
# Out:
#                    File name Seq_Syllables               Duration    Folder  \
# 0     121002212651151905.WAV     [8, 2, 9]  [28341, 19373, 28746]  files201
# 1     121003075445185924.WAV           [9]                [26746]  files201
# 2     121004173718193940.WAV     [9, 9, 9]  [26773, 27746, 25246]  files201
# 3     121005221219635013.WAV     [7, 9, 9]  [26756, 36746, 39246]  files202
# 4     121006093630175196.WAV           [9]                [28746]  files202
# ...                      ...           ...                    ...       ...
# 1577  121217231303167058.WAV          [28]                [46909]  files210
# 1578  121217234551133060.WAV          [22]                [51753]  files210
# 1579  121209230635150780.WAV          [21]                [61046]  files209
# 1580  121210210333207977.WAV          [26]                [48196]  files209
# 1581  121211022010135151.WAV          [13]                [43748]  files209
#
#      labels.label_addressee labels.label_context
# 0                     [209]                  [6]
# 1                     [209]                  [6]
# 2                     [209]                  [6]
# 3                     [209]                  [6]
# 4                     [209]                  [6]
# ...                     ...                  ...
# 1577                  [232]                  [6]
# 1578                  [232]                  [6]
# 1579                  [212]                  [6]
# 1580                  [212]                  [6]
# 1581                  [212]                  [6]
#
# [1582 rows x 6 columns]
